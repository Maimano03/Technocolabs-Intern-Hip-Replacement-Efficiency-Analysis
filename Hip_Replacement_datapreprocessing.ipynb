# %%
import pandas as pd
import numpy as np

file_path = "/content/hospital_inpatient_discharges_totalhipreplacement.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#   health_service_area hospital_county  operating_certificate_number  \
# 0          Western NY        Allegany                        228000
# 1          Western NY        Allegany                        228000
# 2          Western NY        Allegany                        228000
# 3          Western NY        Allegany                        228000
# 4          Western NY        Allegany                        228000
#
#    facility_id                                      facility_name  \
# 0           39  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 1           39  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 2           39  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3           39  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 4           39  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
#
#      age_group zip_code_3_digits gender   race          ethnicity  ...  \
# 0  70 or Older               148      F  White  Not Span/Hispanic  ...
# 1     50 to 69               148      F  White  Not Span/Hispanic  ...
# 2     50 to 69               147      M  White  Not Span/Hispanic  ...
# 3     50 to 69               147      M  White  Not Span/Hispanic  ...
# 4     50 to 69               148      M  White  Not Span/Hispanic  ...
#
#    apr_mdc_code                                apr_mdc_description  \
# 0             8  Diseases and Disorders of the Musculoskeletal ...
# 1             8  Diseases and Disorders of the Musculoskeletal ...
# 2             8  Diseases and Disorders of the Musculoskeletal ...
# 3             8  Diseases and Disorders of the Musculoskeletal ...
# 4             8  Diseases and Disorders of the Musculoskeletal ...
#
#   apr_severity_of_illness_code  apr_severity_of_illness_description  \
# 0                            2                             Moderate
# 1                            2                             Moderate
# 2                            2                             Moderate
# 3                            1                                Minor
# 4                            1                                Minor
#
#    apr_risk_of_mortality apr_medical_surgical_description  \
# 0                  Minor                         Surgical
# 1                  Minor                         Surgical
# 2                  Minor                         Surgical
# 3                  Minor                         Surgical
# 4                  Minor                         Surgical
#
#    attending_provider_license_number operating_provider_license_number  \
# 0                             213053                            213053
# 1                             213053                            213053
# 2                             213053                            213053
# 3                             213053                            213053
# 4                             213053                            213053
#
#    total_charges total_costs
# 0       35681.75    17400.79
# 1       34289.25    16657.95
# 2       30436.00    14703.62
# 3       28699.00    13903.30
# 4       18421.00     8258.43
#
# [5 rows x 30 columns]

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26594 entries, 0 to 26593
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   health_service_area                  26594 non-null  object
#  1   hospital_county                      26594 non-null  object
#  2   operating_certificate_number         26594 non-null  int64
#  3   facility_id                          26594 non-null  int64
#  4   facility_name                        26594 non-null  object
#  5   age_group                            26594 non-null  object
#  6   zip_code_3_digits                    26574 non-null  object
#  7   gender                               26594 non-null  object
#  8   race                                 26594 non-null  object
#  9   ethnicity                            26594 non-null  object
#  10  length_of_stay                       26594 non-null  int64
#  11  type_of_admission                    26594 non-null  object
#  12  patient_disposition                  26594 non-null  object
#  13  discharge_year                       26594 non-null  int64
#  14  ccs_diagnosis_code                   26594 non-null  int64
#  15  ccs_diagnosis_description            26594 non-null  object
#  16  ccs_procedure_code                   26594 non-null  int64
#  17  ccs_procedure_description            26594 non-null  object
#  18  apr_drg_code                         26594 non-null  int64
#  19  apr_drg_description                  26594 non-null  object
#  20  apr_mdc_code                         26594 non-null  int64
#  21  apr_mdc_description                  26594 non-null  object
#  22  apr_severity_of_illness_code         26594 non-null  int64
#  23  apr_severity_of_illness_description  26594 non-null  object
#  24  apr_risk_of_mortality                26594 non-null  object
#  25  apr_medical_surgical_description     26594 non-null  object
#  26  attending_provider_license_number    26594 non-null  int64
#  27  operating_provider_license_number    26594 non-null  int64
#  28  total_charges                        26594 non-null  float64
#  29  total_costs                          26594 non-null  float64
# dtypes: float64(2), int64(11), object(17)
# memory usage: 6.1+ MB
# health_service_area                     0
# hospital_county                         0
# operating_certificate_number            0
# facility_id                             0
# facility_name                           0
# age_group                               0
# zip_code_3_digits                      20
# gender                                  0
# race                                    0
# ethnicity                               0
# length_of_stay                          0
# type_of_admission                       0
# patient_disposition                     0
# discharge_year                          0
# ccs_diagnosis_code                      0
# ccs_diagnosis_description               0
# ccs_procedure_code                      0
# ccs_procedure_description               0
# apr_drg_code                            0
# apr_drg_description                     0
# apr_mdc_code                            0
# apr_mdc_description                     0
# apr_severity_of_illness_code            0
# apr_severity_of_illness_description     0
# apr_risk_of_mortality                   0
# apr_medical_surgical_description        0
# attending_provider_license_number       0
# operating_provider_license_number       0
# total_charges                           0
# total_costs                             0
# dtype: int64

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
for col in cat_cols:
    df[col] = (
        df[col]
        .str.strip()
        .str.lower()
    )

# %%
df.columns
# Out:
# Index(['health_service_area', 'hospital_county',
#        'operating_certificate_number', 'facility_id', 'facility_name',
#        'age_group', 'zip_code_3_digits', 'gender', 'race', 'ethnicity',
#        'length_of_stay', 'type_of_admission', 'patient_disposition',
#        'discharge_year', 'ccs_diagnosis_code', 'ccs_diagnosis_description',
#        'ccs_procedure_code', 'ccs_procedure_description', 'apr_drg_code',
#        'apr_drg_description', 'apr_mdc_code', 'apr_mdc_description',
#        'apr_severity_of_illness_code', 'apr_severity_of_illness_description',
#        'apr_risk_of_mortality', 'apr_medical_surgical_description',
#        'attending_provider_license_number',
#        'operating_provider_license_number', 'total_charges', 'total_costs'],
#       dtype='object')

# %%
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return data[(data[column] >= lower) & (data[column] <= upper)]

# %%
df = remove_outliers_iqr(df, "total_charges")
df = remove_outliers_iqr(df, "total_costs")
df = remove_outliers_iqr(df, "length_of_stay")

# %%
df["charge_to_cost_ratio"] = df["total_charges"] / df["total_costs"]

# %%
df["charge_to_cost_ratio"] = df["charge_to_cost_ratio"].replace([np.inf, -np.inf], np.nan)
df["charge_to_cost_ratio"] = df["charge_to_cost_ratio"].fillna(df["charge_to_cost_ratio"].median())

# %%
df["efficiency_index"] = 1 / (df["total_costs"] * df["length_of_stay"])

# %%
df.describe()
df.isnull().sum()
# Out:
# health_service_area                    0
# hospital_county                        0
# operating_certificate_number           0
# facility_id                            0
# facility_name                          0
# age_group                              0
# zip_code_3_digits                      0
# gender                                 0
# race                                   0
# ethnicity                              0
# length_of_stay                         0
# type_of_admission                      0
# patient_disposition                    0
# discharge_year                         0
# ccs_diagnosis_code                     0
# ccs_diagnosis_description              0
# ccs_procedure_code                     0
# ccs_procedure_description              0
# apr_drg_code                           0
# apr_drg_description                    0
# apr_mdc_code                           0
# apr_mdc_description                    0
# apr_severity_of_illness_code           0
# apr_severity_of_illness_description    0
# apr_risk_of_mortality                  0
# apr_medical_surgical_description       0
# attending_provider_license_number      0
# operating_provider_license_number      0
# total_charges                          0
# total_costs                            0
# charge_to_cost_ratio                   0
# efficiency_index                       0
# dtype: int64

# %%
df.to_csv("cleaned_hip_replacement_data.csv", index=False)
